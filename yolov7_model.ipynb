# %% [markdown]
# #Install Dependencies

# %%
# Download YOLOv7 repository and install requirements
# !git clone https://github.com/WongKinYiu/yolov7
# %cd yolov7
# !pip install -r requirements.txt

# %% [markdown]
# # Download Training Data

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import PIL

from google.colab import files
from google.colab import drive
import pathlib

# %%
def upload_drive():
  drive.mount('/content/drive')

upload_drive()

# %%
# !mkdir -p yolov7data
# !rm -rf yolov7data/*
# !cp '/content/drive/My Drive/AARD/Data/all_images.v1i.yolov7pytorch.zip' ./yolov7data

# %%
# !rm -rf /content/train /content/test /content/valid
# !cd /content && unzip /content/yolov7/yolov7data/all_images.v1i.yolov7pytorch.zip

# %% [markdown]
# # Training

# %%
# %cd /content/yolov7
# !wget "https://github.com/WongKinYiu/yolov7/releases/download/v0.1/yolov7-e6.pt"

# %%
# begin training
# %cd /content/yolov7
# !python train_aux.py --batch 8 --img 1024 1024 --cfg cfg/training/yolov7-e6.yaml --epochs 150 --data /content/data.yaml --weights '/content/yolov7/yolov7-e6.pt'
# Out:
# /content/yolov7
# YOLOR 🚀 v0.1-89-g4789bd1 torch 1.12.1+cu102 CUDA:0 (Tesla P100-PCIE-16GB, 16280.875MB)
#
# Namespace(adam=False, artifact_alias='latest', batch_size=8, bbox_interval=-1, bucket='', cache_images=False, cfg='cfg/training/yolov7-e6.yaml', data='/content/data.yaml', device='', entity=None, epochs=150, evolve=False, exist_ok=False, global_rank=-1, hyp='data/hyp.scratch.p5.yaml', image_weights=False, img_size=[1024, 1024], label_smoothing=0.0, linear_lr=False, local_rank=-1, multi_scale=False, name='exp', noautoanchor=False, nosave=False, notest=False, project='runs/train', quad=False, rect=False, resume=False, save_dir='runs/train/exp20', save_period=-1, single_cls=False, sync_bn=False, total_batch_size=8, upload_dataset=False, weights='/content/yolov7/yolov7-e6.pt', workers=8, world_size=1)
# tensorboard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# ...

# %%
# !cp runs/train/exp20/weights/best.pt "/content/drive/My Drive/AARD/yolov7-e6-all-best.pt"

# %% [markdown]
# # Evaluation

# %%
# Run evaluation
# !python detect.py --weights runs/train/exp20/weights/best.pt --conf 0.1 --source /content/test/images

# %%
#display inference on ALL test images

import glob
from IPython.display import Image, display

i = 0
limit = 100 # max images to print
for imageName in glob.glob('/content/yolov7/runs/detect/exp/*.jpg'): 
    if i < limit:
      display(Image(filename=imageName))
      print("\n")
      print(imageName)
    i = i + 1
